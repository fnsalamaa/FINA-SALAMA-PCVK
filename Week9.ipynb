# %% [markdown]
# <a href="https://colab.research.google.com/github/fnsalamaa/FINA-SALAMA-PCVK/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**✩˚｡⋆ WEEK 8 PCVK ✩˚｡⋆**
#
# ### Name : Fina Salama Qowlam Hareny
#
# #### No    : 08 / 2141720164
#
# ####Class : TI-3I

# %% [markdown]
# ----
# ##**⋰˚☆ MODULE 8 ⋰˚☆**
# ###**Morphology**
# Morphological operation is an image processing technique that is based on the
# shape of the segment or region in the image . Operation morphology is usually applied
# to the image of the binary primary and a grayscale images. Based on the binary value,
# it can be distinguished which part of the object and which part is not an object or a
# background. Although often used in image binary, operating morphology is often also
# used the grayscale images. Some operations morphology that can be done is Dilation,
# Erosion , Closing and Opening

# %% [markdown]
# 1. The following are steps that can be taken :
# - **Access the files contained on the drive**

# %%
from google.colab import drive

# Acessing Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. Import some libraries following that will be used during the test try practicum weeks
# to 6 below.**

# %%
# Import necessary libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Display the image
img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')
plt.imshow(img)

# %% [markdown]
# **3. Make the dilation operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square without using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Image of Dilation Results')
# Out:
# (<Axes: title={'center': 'Image of Dilation Results'}>,
# ...
#  Text(0.5, 1.0, 'Image of Dilation Results'))

# %% [markdown]
# **4. Make the erosion operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square without using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Results Image')
# Out:
# (<Axes: title={'center': 'Erosion Results Image'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Results Image'))

# %% [markdown]
# **5. Make the dilation operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square using the OpenCV morphology library, thus generating
# the results shows in the figure (Use image “j.png”)**

# %%
ret, thresh = cv2.threshold(img, 127, 225, cv2.THRESH_BINARY)
kernel = np.ones((5,5),np.uint8)
dilasi = cv2.dilate(thresh,kernel,iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilasi),plt.title('Citra Dilation')
# Out:
# (<Axes: title={'center': 'Citra Dilation'}>,
# ...
#  Text(0.5, 1.0, 'Citra Dilation'))

# %% [markdown]
# **6. Make the erotion operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square using the OpenCV morphology library, thus generating
# the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv2.morphologyEx(img, cv2.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Results Image')
# Out:
# (<Axes: title={'center': 'Erosion Results Image'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Results Image'))

# %% [markdown]
# **7. Make the Opening operation and show the results on the image of the Structuring
# Element shaped 7 x 7 square with and without using the OpenCV morphology library,
# thus generating the results shows in the figure (Use image “j.png”)**

# %%
# Structuring Element Opening with Morphology
kernel = np.ones((7,7), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Opening Result Image')
# Out:
# (<Axes: title={'center': 'Opening Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Opening Result Image'))

# %%
# Structuring Element Opening without Morphology
element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Opening Result Image')
# Out:
# (<Axes: title={'center': 'Opening Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Opening Result Image'))

# %% [markdown]
# **8. Make the Closing operation and show the results on the image of the Structuring
# Element shaped 7 x 7 square with and without using the OpenCV morphology library,
# thus generating the results shows in the figure (Use image “j.png”)**

# %%
# Structuring Element Closing with Morphology
kernel = np.ones((7,7), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Closing Result Image')
# Out:
# (<Axes: title={'center': 'Closing Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Closing Result Image'))

# %%
# Structuring Element Closing without Morphology
element = cv2.getStructuringElement(cv2.MORPH_RECT,(7,7))
erosion_dst = cv2.erode(img, element)
opening_dst = cv2.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Closing Result Image')
# Out:
# (<Axes: title={'center': 'Closing Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Closing Result Image'))

# %% [markdown]
# **9. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3x3 and 5x5 Cross using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')
element = cv2.getStructuringElement(cv2.MORPH_CROSS, (3, 3))
dilation = cv2.dilate(img, element, iterations=1)  # Fix: use cv2.dilate() and element instead of kernel

print("SED = Cross 3")
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(dilation), plt.title('Dilation Results Image')
plt.show()  # Added plt.show() to display the images

element = cv2.getStructuringElement(cv2.MORPH_CROSS, (5, 5))
dilation = cv2.dilate(img, element, iterations = 1)
print("SED = Cross 5")
plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilation Results Image')
# Out:
# SED = Cross 3
# SED = Cross 5
# (<Axes: title={'center': 'Dilation Results Image'}>,
# ...
#  Text(0.5, 1.0, 'Dilation Results Image'))

# %% [markdown]
# **10. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3x3 and 5x5 Circular using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')

# Define the structuring element
element = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
dilation = cv2.dilate(img, element, iterations=1)  # Use 'element' instead of 'kernel'
print("SED = circle 3")
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(dilation), plt.title('Dilation Results Image')
plt.show()  # Added plt.show() to display the images

# Define a different structuring element
element = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
dilation = cv2.dilate(img, element, iterations=1)  # Use 'element' instead of 'kernel'
print("SED = circle 5")
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(dilation), plt.title('Dilation Results Image')
plt.show()  # Added plt.show() to display the images
# Out:
# SED = circle 3
# SED = circle 5

# %% [markdown]
# **11. Make the Erotion operation and show the results on the image of the Structuring
# Element shaped 3x3 and 5x5 Rectangle using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')

# Define a different structuring element
element = cv2.getStructuringElement(cv2.MORPH_RECT,(3,5))
Erotion = cv2.erode(img,element,iterations = 1)
print("SE = Rectangle 3x5")
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(Erotion), plt.title('Erotion Result Image')
# Out:
# SE = Rectangle 3x5
# (<Axes: title={'center': 'Erotion Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Erotion Result Image'))

# %%
# Define a different structuring element
element = cv2.getStructuringElement(cv2.MORPH_RECT,(5,7))
erosion = cv2.erode(img,element,iterations = 1)
print("SE = Rectangle 5x7")
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erotion Result Image')
# Out:
# SE = Rectangle 5x7
# (<Axes: title={'center': 'Erotion Result Image'}>,
# ...
#  Text(0.5, 1.0, 'Erotion Result Image'))

# %% [markdown]
# **12. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3 and 5 Line Vertical using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/j.png')

kernel = np.ones((3,1),np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
print("SE = Line Vertikal 3")
plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
